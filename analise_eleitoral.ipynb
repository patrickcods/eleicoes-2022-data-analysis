# %%
# Instalando os pacotes que serão utilizados
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
try:
    candidaturas_df = pd.read_csv('receitas_candidatos.csv', sep=';', encoding='iso-8859-1')
    print("CSV lido com sucesso")
except FileNotFoundError:
    print("Arquivo não encontrado!")
# Out:
# CSV lido com sucesso

# %%
candidaturas_df.tail()
# Out:
#         Ano de eleição       Cargo    Esfera Esfera partidária  \
# 361174            2022  Presidente  Nacional     Não se aplica
# 361175            2022  Presidente  Nacional     Não se aplica
# 361176            2022  Presidente  Nacional     Não se aplica
# 361177            2022  Presidente  Nacional     Não se aplica
# 361178            2022  Presidente  Nacional     Não se aplica
#
#                  Espécie receita Fonte de receita Município  \
# 361174  Transferência eletrônica  OUTROS RECURSOS         -
# 361175  Transferência eletrônica  OUTROS RECURSOS         -
# 361176  Transferência eletrônica  OUTROS RECURSOS         -
# 361177  Transferência eletrônica  OUTROS RECURSOS         -
# 361178  Transferência eletrônica  OUTROS RECURSOS         -
#
#                              Nome candidato                  Nome doador  \
# 361174  VERA LUCIA PEREIRA DA SILVA SALGADO   SABRINA STEFANNY MARCELINO
# 361175  VERA LUCIA PEREIRA DA SILVA SALGADO                 SADAO MAKINO
# 361176  VERA LUCIA PEREIRA DA SILVA SALGADO     SILVIO SINEDINO PINHEIRO
# 361177  VERA LUCIA PEREIRA DA SILVA SALGADO     VERUSKA OLIVEIRA TENORIO
# 361178  VERA LUCIA PEREIRA DA SILVA SALGADO  VICTOR OLIVEIRA DE MESQUITA
#
#                   Origem da receita Partido  Quilombola Região  \
# 361174  Recursos de pessoas físicas    PSTU         NaN      -
# 361175  Recursos de pessoas físicas    PSTU         NaN      -
# 361176  Recursos de pessoas físicas    PSTU         NaN      -
# 361177  Recursos de pessoas físicas    PSTU         NaN      -
# 361178  Recursos de pessoas físicas    PSTU         NaN      -
#
#        Situação de candidatura  Situação de julgamento  \
# 361174                    Apto                     NaN
# 361175                    Apto                     NaN
# 361176                    Apto                     NaN
# 361177                    Apto                     NaN
# 361178                    Apto                     NaN
#
#        Situação de totalização  UF  Valor de receita       Data de carga
# 361174              Não eleito  BR         R$ 200.00 2026-06-28 15:00:30
# 361175              Não eleito  BR         R$ 480.00 2026-06-28 15:00:30
# 361176              Não eleito  BR       R$ 2,128.00 2026-06-28 15:00:30
# 361177              Não eleito  BR         R$ 360.00 2026-06-28 15:00:30
# 361178              Não eleito  BR         R$ 600.00 2026-06-28 15:00:30

# %%
# candidaturas_df.info()
candidaturas_df['Valor de receita'] = candidaturas_df['Valor de receita'].str.replace(',','.')
candidaturas_df['Valor de receita'] = candidaturas_df['Valor de receita'].astype(float)

# %%
candidaturas_df.head()
# Out:
#    Ano de eleição       Cargo    Esfera Esfera partidária Espécie receita  \
# 0            2022  Presidente  Nacional     Não se aplica              --
# 1            2022  Presidente  Nacional     Não se aplica              --
# 2            2022  Presidente  Nacional     Não se aplica              --
# 3            2022  Presidente  Nacional     Não se aplica          Cheque
# 4            2022  Presidente  Nacional     Não se aplica          Cheque
#
#    Fonte de receita Município                  Nome candidato  \
# 0    FUNDO ESPECIAL         -       LUIZ INÁCIO LULA DA SILVA
# 1  FUNDO PARTIDARIO         -          JAIR MESSIAS BOLSONARO
# 2   OUTROS RECURSOS         -          JAIR MESSIAS BOLSONARO
# 3    FUNDO ESPECIAL         -  LEONARDO PÉRICLES VIEIRA ROQUE
# 4   OUTROS RECURSOS         -          JAIR MESSIAS BOLSONARO
#
#              Nome doador                      Origem da receita Partido  \
# 0                  #NULO  Rendimentos de aplicações financeiras      PT
# 1                  #NULO  Rendimentos de aplicações financeiras      PL
# 2                  #NULO  Rendimentos de aplicações financeiras      PL
# 3        UNIDADE POPULAR           Recursos de partido político      UP
# 4  ADAIR ANTONIO BOLDRIN            Recursos de pessoas físicas      PL
#
#    Quilombola Região Situação de candidatura  Situação de julgamento  \
# 0         NaN      -                    Apto                     NaN
# 1         NaN      -                    Apto                     NaN
# 2         NaN      -                    Apto                     NaN
# 3         NaN      -                    Apto                     NaN
# 4         NaN      -                    Apto                     NaN
#
#   Situação de totalização  UF  Valor de receita        Data de carga
# 0                2º turno  BR          65002.55  2026-06-28 15:00:30
# 1                2º turno  BR          29567.32  2026-06-28 15:00:30
# 2                2º turno  BR         298458.46  2026-06-28 15:00:30
# 3              Não eleito  BR        1275436.94  2026-06-28 15:00:30
# 4                2º turno  BR          40000.00  2026-06-28 15:00:30

# %%
# candidaturas_df.info()

# %%
candidaturas_df['Data de carga'] = pd.to_datetime(candidaturas_df['Data de carga'])

# %%
# candidaturas_df.info()

# %%
df_receita_por_candidato = candidaturas_df.groupby(['Nome candidato', 'Partido', 'Situação de totalização'])['Valor de receita'].sum().sort_values(ascending=False).reset_index()

pd.options.display.float_format = 'R$ {:,.2f}'.format


df_receita_por_candidato.head()
# Out:
#               Nome candidato Partido Situação de totalização  Valor de receita
# 0  LUIZ INÁCIO LULA DA SILVA      PT                2º turno R$ 135,539,287.82
# 1     JAIR MESSIAS BOLSONARO      PL                2º turno R$ 126,127,517.46
# 2        SIMONE NASSAR TEBET     MDB              Não eleito  R$ 38,828,942.91
# 3    SORAYA VIEIRA THRONICKE   UNIÃO              Não eleito  R$ 36,675,548.85
# 4        CIRO FERREIRA GOMES     PDT              Não eleito  R$ 36,013,770.24

# %%
sns.barplot(data = df_receita_por_candidato , x= 'Partido', y= 'Valor de receita',hue= 'Partido', palette='Set1', legend=False)
plt.show()

# %%
candidaturas_df.head()
# Out:
#    Ano de eleição       Cargo    Esfera Esfera partidária Espécie receita  \
# 0            2022  Presidente  Nacional     Não se aplica              --
# 1            2022  Presidente  Nacional     Não se aplica              --
# 2            2022  Presidente  Nacional     Não se aplica              --
# 3            2022  Presidente  Nacional     Não se aplica          Cheque
# 4            2022  Presidente  Nacional     Não se aplica          Cheque
#
#    Fonte de receita Município                  Nome candidato  \
# 0    FUNDO ESPECIAL         -       LUIZ INÁCIO LULA DA SILVA
# 1  FUNDO PARTIDARIO         -          JAIR MESSIAS BOLSONARO
# 2   OUTROS RECURSOS         -          JAIR MESSIAS BOLSONARO
# 3    FUNDO ESPECIAL         -  LEONARDO PÉRICLES VIEIRA ROQUE
# 4   OUTROS RECURSOS         -          JAIR MESSIAS BOLSONARO
#
#              Nome doador                      Origem da receita Partido  \
# 0                  #NULO  Rendimentos de aplicações financeiras      PT
# 1                  #NULO  Rendimentos de aplicações financeiras      PL
# 2                  #NULO  Rendimentos de aplicações financeiras      PL
# 3        UNIDADE POPULAR           Recursos de partido político      UP
# 4  ADAIR ANTONIO BOLDRIN            Recursos de pessoas físicas      PL
#
#    Quilombola Região Situação de candidatura  Situação de julgamento  \
# 0         NaN      -                    Apto                     NaN
# 1         NaN      -                    Apto                     NaN
# 2         NaN      -                    Apto                     NaN
# 3         NaN      -                    Apto                     NaN
# 4         NaN      -                    Apto                     NaN
#
#   Situação de totalização  UF  Valor de receita       Data de carga
# 0                2º turno  BR      R$ 65,002.55 2026-06-28 15:00:30
# 1                2º turno  BR      R$ 29,567.32 2026-06-28 15:00:30
# 2                2º turno  BR     R$ 298,458.46 2026-06-28 15:00:30
# 3              Não eleito  BR   R$ 1,275,436.94 2026-06-28 15:00:30
# 4                2º turno  BR      R$ 40,000.00 2026-06-28 15:00:30

# %%
seg_turno_df = candidaturas_df[candidaturas_df['Situação de totalização'] == '2º turno']
seg_turno_df.pivot_table(index= 'Nome candidato', columns= 'Fonte de receita', values= 'Valor de receita', aggfunc= 'sum')
# Out:
# Fonte de receita             FUNDO ESPECIAL  FUNDO PARTIDARIO  OUTROS RECURSOS
# Nome candidato
# JAIR MESSIAS BOLSONARO      R$ 1,988,972.68  R$ 29,447,388.77 R$ 94,691,156.01
# LUIZ INÁCIO LULA DA SILVA R$ 125,119,008.86     R$ 242,092.25 R$ 10,178,186.71

# %%
try:
    votos_df = pd.read_csv('votacao_candidato.csv', sep=';', encoding='iso-8859-1')
    print('CSV lido com sucesso!')
except FileNotFoundError:
    print('Arquivo não encontrado!')
# Out:
# CSV lido com sucesso!

# %%
votos_df.sample(10)
# Out:
#        Ano de eleição       Cargo  Código município Cor/raça Estado civil  \
# 15808            2022  Presidente             71072   Branca    Casado(a)
# 61023            2022  Presidente             56812   Branca    Casado(a)
# 67174            2022  Presidente             71455   Branca    Casado(a)
# 21598            2022  Presidente             84956    Preta  Solteiro(a)
# 9773             2022  Presidente             30708   Branca    Casado(a)
# 41714            2022  Presidente             77410   Branca    Casado(a)
# 68497            2022  Presidente             98450   Branca    Casado(a)
# 37292            2022  Presidente             27430   Branca    Casado(a)
# 19210            2022  Presidente             41238   Branca    Casado(a)
# 3693             2022  Presidente             99155   Branca  Solteiro(a)
#
#        Faixa etária     Gênero      Grau de instrução  \
# 15808  50 a 54 anos   Feminino      Superior completo
# 61023  45 a 49 anos   Feminino      Superior completo
# 67174  50 a 54 anos   Feminino      Superior completo
# 21598  40 a 44 anos  Masculino  Ensino Médio completo
# 9773   45 a 49 anos   Feminino      Superior completo
# 41714  65 a 69 anos  Masculino      Superior completo
# 68497  55 a 59 anos  Masculino      Superior completo
# 37292  65 a 69 anos  Masculino      Superior completo
# 19210  80 a 84 anos  Masculino      Superior completo
# 3693   50 a 54 anos   Feminino      Superior completo
#
#                      Município                  Nome candidato  ...  \
# 15808                SÃO PAULO             SIMONE NASSAR TEBET  ...
# 61023                PINHEIROS         SORAYA VIEIRA THRONICKE  ...
# 67174                 SOROCABA             SIMONE NASSAR TEBET  ...
# 21598         SILVEIRA MARTINS  LEONARDO PÉRICLES VIEIRA ROQUE  ...
# 9773                     TUNIS         SORAYA VIEIRA THRONICKE  ...
# 41714         PARAÍSO DO NORTE          JAIR MESSIAS BOLSONARO  ...
# 68497  SÃO SEBASTIÃO DO UATUMÃ      LUIZ FELIPE CHAVES D'AVILA  ...
# 37292            COQUEIRO SECO          JAIR MESSIAS BOLSONARO  ...
# 19210           BELO HORIZONTE               JOSE MARIA EYMAEL  ...
# 3693             PUERTO IGUAZÚ             SOFIA PADUA MANZANO  ...
#
#                         Ocupação Partido    Região Situação totalização Turno  \
# 15808                   Advogado     MDB   SUDESTE           Não Eleito     1
# 61023                    Senador   UNIÃO   SUDESTE           Não Eleito     1
# 67174                   Advogado     MDB   SUDESTE           Não Eleito     1
# 21598        Técnico de Mecânica      UP       SUL           Não Eleito     1
# 9773                     Senador   UNIÃO  EXTERIOR           Não Eleito     1
# 41714    Presidente da República      PL       SUL        Segundo turno     1
# 68497         Cientista Político    NOVO     NORTE           Não Eleito     1
# 37292    Presidente da República      PL  NORDESTE        Segundo turno     1
# 19210                   Advogado      DC   SUDESTE           Não Eleito     1
# 3693   Servidor Público Estadual     PCB  EXTERIOR           Não Eleito     1
#
#        UF Zona  Votos válidos  Votos nominais        Data de carga
# 15808  SP  351          98329            7626  2026-07-01 02:18:42
# 61023  ES   39          13378              31  2026-07-01 02:18:42
# 67174  SP  137          59923            4141  2026-07-01 02:18:42
# 21598  RS   41           1771               0  2026-07-01 02:18:42
# 9773   ZZ    1             14               0  2026-07-01 02:18:42
# 41714  PR  100           7709            3866  2026-07-01 02:18:42
# 68497  AM   27           5512              10  2026-07-01 02:18:42
# 37292  AL    8           3959            1300  2026-07-01 02:18:42
# 19210  MG  332          88277               9  2026-07-01 02:18:42
# 3693   ZZ    1              4               0  2026-07-01 02:18:42
#
# [10 rows x 21 columns]

# %%
votos_por_cand_df = votos_df.groupby('Nome candidato')['Votos nominais'].sum().reset_index().sort_values(by= 'Votos nominais', ascending= False)
votos_por_cand_df
# Out:
#                          Nome candidato  Votos nominais
# 6             LUIZ INÁCIO LULA DA SILVA        57259504
# 1                JAIR MESSIAS BOLSONARO        51072345
# 7                   SIMONE NASSAR TEBET         4915423
# 0                   CIRO FERREIRA GOMES         3599287
# 9               SORAYA VIEIRA THRONICKE          600955
# 5            LUIZ FELIPE CHAVES D'AVILA          559708
# 3            KELMON LUIS DA SILVA SOUZA           81129
# 4        LEONARDO PÉRICLES VIEIRA ROQUE           53519
# 8                   SOFIA PADUA MANZANO           45620
# 10  VERA LUCIA PEREIRA DA SILVA SALGADO           25625
# 2                     JOSE MARIA EYMAEL           16604

# %%
candidato_total_df = pd.merge(df_receita_por_candidato, votos_por_cand_df, on= 'Nome candidato')

candidato_total_df
# Out:
#                         Nome candidato Partido Situação de totalização  \
# 0            LUIZ INÁCIO LULA DA SILVA      PT                2º turno
# 1               JAIR MESSIAS BOLSONARO      PL                2º turno
# 2                  SIMONE NASSAR TEBET     MDB              Não eleito
# 3              SORAYA VIEIRA THRONICKE   UNIÃO              Não eleito
# 4                  CIRO FERREIRA GOMES     PDT              Não eleito
# 5           KELMON LUIS DA SILVA SOUZA     PTB              Não eleito
# 6  VERA LUCIA PEREIRA DA SILVA SALGADO    PSTU              Não eleito
# 7       LEONARDO PÉRICLES VIEIRA ROQUE      UP              Não eleito
# 8                    JOSE MARIA EYMAEL      DC              Não eleito
# 9                  SOFIA PADUA MANZANO     PCB              Não eleito
#
#    Valor de receita  Votos nominais
# 0 R$ 135,539,287.82        57259504
# 1 R$ 126,127,517.46        51072345
# 2  R$ 38,828,942.91         4915423
# 3  R$ 36,675,548.85          600955
# 4  R$ 36,013,770.24         3599287
# 5   R$ 1,545,000.00           81129
# 6   R$ 1,359,238.35           25625
# 7   R$ 1,307,411.22           53519
# 8   R$ 1,176,433.50           16604
# 9      R$ 25,940.50           45620

# %%
candidato_total_df['Custo por voto'] = candidato_total_df['Valor de receita'] / candidato_total_df['Votos nominais']

# %%
candidato_total_df
# Out:
#                         Nome candidato Partido Situação de totalização  \
# 0            LUIZ INÁCIO LULA DA SILVA      PT                2º turno
# 1               JAIR MESSIAS BOLSONARO      PL                2º turno
# 2                  SIMONE NASSAR TEBET     MDB              Não eleito
# 3              SORAYA VIEIRA THRONICKE   UNIÃO              Não eleito
# 4                  CIRO FERREIRA GOMES     PDT              Não eleito
# 5           KELMON LUIS DA SILVA SOUZA     PTB              Não eleito
# 6  VERA LUCIA PEREIRA DA SILVA SALGADO    PSTU              Não eleito
# 7       LEONARDO PÉRICLES VIEIRA ROQUE      UP              Não eleito
# 8                    JOSE MARIA EYMAEL      DC              Não eleito
# 9                  SOFIA PADUA MANZANO     PCB              Não eleito
#
#    Valor de receita  Votos nominais  Custo por voto
# 0 R$ 135,539,287.82        57259504         R$ 2.37
# 1 R$ 126,127,517.46        51072345         R$ 2.47
# 2  R$ 38,828,942.91         4915423         R$ 7.90
# 3  R$ 36,675,548.85          600955        R$ 61.03
# 4  R$ 36,013,770.24         3599287        R$ 10.01
# 5   R$ 1,545,000.00           81129        R$ 19.04
# 6   R$ 1,359,238.35           25625        R$ 53.04
# 7   R$ 1,307,411.22           53519        R$ 24.43
# 8   R$ 1,176,433.50           16604        R$ 70.85
# 9      R$ 25,940.50           45620         R$ 0.57

# %%
sns.scatterplot(data= candidato_total_df, x= 'Valor de receita', y= 'Votos nominais', hue= 'Partido', palette='Set1', legend=True)
plt.show()

# %%
# .median() 
candidato_total_df['Média custo por voto'] = candidato_total_df['Custo por voto'].mean()
candidato_total_df['Mediana custo por voto'] = candidato_total_df['Custo por voto'].median()

# %%
candidato_total_df
# Out:
#                         Nome candidato Partido Situação de totalização  \
# 0            LUIZ INÁCIO LULA DA SILVA      PT                2º turno
# 1               JAIR MESSIAS BOLSONARO      PL                2º turno
# 2                  SIMONE NASSAR TEBET     MDB              Não eleito
# 3              SORAYA VIEIRA THRONICKE   UNIÃO              Não eleito
# 4                  CIRO FERREIRA GOMES     PDT              Não eleito
# 5           KELMON LUIS DA SILVA SOUZA     PTB              Não eleito
# 6  VERA LUCIA PEREIRA DA SILVA SALGADO    PSTU              Não eleito
# 7       LEONARDO PÉRICLES VIEIRA ROQUE      UP              Não eleito
# 8                    JOSE MARIA EYMAEL      DC              Não eleito
# 9                  SOFIA PADUA MANZANO     PCB              Não eleito
#
#    Valor de receita  Votos nominais  Custo por voto  Média custo por voto  \
# 0 R$ 135,539,287.82        57259504         R$ 2.37              R$ 25.17
# 1 R$ 126,127,517.46        51072345         R$ 2.47              R$ 25.17
# 2  R$ 38,828,942.91         4915423         R$ 7.90              R$ 25.17
# 3  R$ 36,675,548.85          600955        R$ 61.03              R$ 25.17
# 4  R$ 36,013,770.24         3599287        R$ 10.01              R$ 25.17
# 5   R$ 1,545,000.00           81129        R$ 19.04              R$ 25.17
# 6   R$ 1,359,238.35           25625        R$ 53.04              R$ 25.17
# 7   R$ 1,307,411.22           53519        R$ 24.43              R$ 25.17
# 8   R$ 1,176,433.50           16604        R$ 70.85              R$ 25.17
# 9      R$ 25,940.50           45620         R$ 0.57              R$ 25.17
#
#    Mediana custo por voto
# 0                R$ 14.52
# 1                R$ 14.52
# 2                R$ 14.52
# 3                R$ 14.52
# 4                R$ 14.52
# 5                R$ 14.52
# 6                R$ 14.52
# 7                R$ 14.52
# 8                R$ 14.52
# 9                R$ 14.52

# %%
PT_PL_df= seg_turno_df.groupby('Nome candidato')['Valor de receita'].sum().reset_index()
PT_PL_df
# Out:
#               Nome candidato  Valor de receita
# 0     JAIR MESSIAS BOLSONARO R$ 126,127,517.46
# 1  LUIZ INÁCIO LULA DA SILVA R$ 135,539,287.82

# %%
porcentagem_receita_PT_PL = float(PT_PL_df['Valor de receita'].sum() / candidato_total_df['Valor de receita'].sum() * 100)
print(f'A porcentagem de receitas de Jair Bolsonaro e Lula são aproximadamente {porcentagem_receita_PT_PL:.3f}% do total de receitas')
# Out:
# A porcentagem de receitas de Jair Bolsonaro e Lula são aproximadamente 69.114% do total de receitas
